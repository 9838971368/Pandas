# %%
import pandas as pd
sar = pd.Series(data = [10,20,30,40,50], index=['a','b','c','d','e'])

# %%
sar
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
sar.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
sar.iloc[0]
# Out:
# 10

# %%
sar[[0,1]]
# Out:
# a    10
# b    20
# dtype: int64

# %%
2 in sar
# Out:
# False

# %%
"a" in sar
# Out:
# True

# %%
sar.iloc[0]
# Out:
# 10

# %%
sar*2
# Out:
# a     20
# b     40
# c     60
# d     80
# e    100
# dtype: int64

# %%
sar**2
from pandas import Series, DataFrame

# %%
sdata = {'a': 35000, 'b': 71000, 'c': 16000, 'd': 5000}

# %%
sdata
# Out:
# {'a': 35000, 'b': 71000, 'c': 16000, 'd': 5000}

# %%
obj3 = pd.Series(sdata)

# %%
obj3
# Out:
# a    35000
# b    71000
# c    16000
# d     5000
# dtype: int64

# %%
states = ['Up', 'delhi', 'panjab', 'rajasthan']
obj4 = pd.Series(states,index = ['a','b','c','d'])

# %%
obj4
# Out:
# a           Up
# b        delhi
# c       panjab
# d    rajasthan
# dtype: object

# %%
pd.isnull(obj4)
# Out:
# a    False
# b    False
# c    False
# d    False
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# a    True
# b    True
# c    True
# d    True
# dtype: bool

# %%
obj3
# Out:
# a    35000
# b    71000
# c    16000
# d     5000
# dtype: int64

# %%
obj4
# Out:
# a           Up
# b        delhi
# c       panjab
# d    rajasthan
# dtype: object

# %%
obj3+obj4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     675         try:
# --> 676             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     677         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ...

# %%
obj4.name = 'india'

# %%
obj4.index.name = 'state'

# %%
obj4
# Out:
# state
# a           Up
# b        delhi
# c       panjab
# d    rajasthan
# Name: india, dtype: object

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#    pop   state  year
# 0  1.5    Ohio  2000
# 1  1.7    Ohio  2001
# 2  3.6    Ohio  2002
# 3  2.4  Nevada  2001
# 4  2.9  Nevada  2002
# 5  3.2  Nevada  2003

# %%
data
# Out:
# {'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2],
#  'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
#  'year': [2000, 2001, 2002, 2001, 2002, 2003]}

# %%
pd.Series(data)
# Out:
# pop                  [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
# state    [Ohio, Ohio, Ohio, Nevada, Nevada, Nevada]
# year           [2000, 2001, 2002, 2001, 2002, 2003]
# dtype: object

# %%
pd.DataFrame(data)
# Out:
#    pop   state  year
# 0  1.5    Ohio  2000
# 1  1.7    Ohio  2001
# 2  3.6    Ohio  2002
# 3  2.4  Nevada  2001
# 4  2.9  Nevada  2002
# 5  3.2  Nevada  2003

# %%
# spacify the seqence
pd.DataFrame(data, columns=['year', 'state', 'pop', 'pk'])
# Out:
#    year   state  pop   pk
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %% [markdown]
# If you pass a column that isn’t contained in the dict, it will appear with missing values
# in the result:

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
        index=['one', 'two', 'three', 'four',
        'five', 'six'])

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
frame2.loc['three']
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %%
frame2['debt'] = [1,2,3,8,9,10]

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5     1
# two    2001    Ohio  1.7     2
# three  2002    Ohio  3.6     3
# four   2001  Nevada  2.4     8
# five   2002  Nevada  2.9     9
# six    2003  Nevada  3.2    10

# %%
import numpy as np
frame2['debt'] = np.arange(2,8)

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5     2
# two    2001    Ohio  1.7     3
# three  2002    Ohio  3.6     4
# four   2001  Nevada  2.4     5
# five   2002  Nevada  2.9     6
# six    2003  Nevada  3.2     7

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=['seven', 'four', 'five'])

# %%
frame2['debt'] = val
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7   NaN
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
frame2['eastern'] = frame2.state == 'Ohio'

# %%
frame2
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7   NaN     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False
# six    2003  Nevada  3.2   NaN    False

# %%
del frame2['eastern']

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %% [markdown]
# # nested dict of dicts:

# %%
pop = {'up': {2001: 2.4, 2002: 2.9},'delhi': {2000: 1.5, 2001: 1.7, 2002: 3.6}}

# %%
frame3 = pd.DataFrame(pop)
frame3
# Out:
#       delhi   up
# 2000    1.5  NaN
# 2001    1.7  2.4
# 2002    3.6  2.9

# %% [markdown]
# # If the nested dict is passed to the DataFrame, pandas will interpret the outer dict keysas the columns and the inner keys as the row indices:

# %% [markdown]
# You can transpose the DataFrame (swap rows and columns) with similar syntax to a
# NumPy array:

# %%
frame3
# Out:
#       delhi   up
# 2000    1.5  NaN
# 2001    1.7  2.4
# 2002    3.6  2.9

# %%
frame3.T
# Out:
#        2000  2001  2002
# delhi   1.5   1.7   3.6
# up      NaN   2.4   2.9

# %%
del frame3['delhi']

# %%
frame3
# Out:
#        up
# 2000  NaN
# 2001  2.4
# 2002  2.9

# %%
obj = pd.Series(range(3), index=['a', 'b', 'c'])

# %%
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
labels = pd.Index(np.arange(3))

# %%
labels
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
my = pd.Series([11,22,33], index = labels)

# %%
my
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
my. is labels
# Out:
#   File "<ipython-input-58-00fefefb81e2>", line 1
#     my. is labels
#          ^
# SyntaxError: invalid syntax

# %%
my.index
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
dup_labels = pd.Index(['foo', 'foo', 'bar', 'bar'])
dup_labels
# Out:
# Index(['foo', 'foo', 'bar', 'bar'], dtype='object')

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])

# %%
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0,1,2])
obj3
# Out:
# 0      blue
# 1    purple
# 2    yellow
# dtype: object

# %%
obj3.reindex(range(6), method='ffill')
# Out:
# 0      blue
# 1    purple
# 2    yellow
# 3    yellow
# 4    yellow
# 5    yellow
# dtype: object

# %%
movies = pd.read_csv("Movies.csv")
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print(movies.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags = pd.read_csv("Tags.csv")

# %%
print(tags.head())
# Out:
#    userId  movieId                      tag   timestamp
# 0      15      339  sandra 'boring' bullock  1138537770
# 1      15     1955                  dentist  1193435061
# 2      15     7478                 Cambodia  1170560997
# 3      15    32892                  Russian  1170626366
# 4      15    34162              forgettable  1141391765

# %%
rating = pd.read_csv("ratings.csv")

# %%
print(rating.head())
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
del rating["timestamp"]
del tags["timestamp"]

# %%
tags.head()
# Out:
#    userId  movieId                      tag
# 0      15      339  sandra 'boring' bullock
# 1      15     1955                  dentist
# 2      15     7478                 Cambodia
# 3      15    32892                  Russian
# 4      15    34162              forgettable

# %% [markdown]
# # describe

# %%
rating.describe()
# Out:
#               userId        movieId         rating
# count  100004.000000  100004.000000  100004.000000
# mean      347.011310   12548.664363       3.543608
# std       195.163838   26369.198969       1.058064
# min         1.000000       1.000000       0.500000
# 25%       182.000000    1028.000000       3.000000
# 50%       367.000000    2406.500000       4.000000
# 75%       520.000000    5418.000000       4.000000
# max       671.000000  163949.000000       5.000000

# %% [markdown]
# # Correlation

# %% [markdown]
# Negitive and positive. if we have x and y variables and negitive corr applied then x inceases and y decreses

# %%
corr = rating.corr()
corr
# Out:
#            userId   movieId    rating
# userId   1.000000  0.007126  0.010467
# movieId  0.007126  1.000000 -0.028894
# rating   0.010467 -0.028894  1.000000

# %%
rating['userId'].max()
# Out:
# 671

# %%
rating.min()
# Out:
# userId     1.0
# movieId    1.0
# rating     0.5
# dtype: float64

# %%
rating.mean()
# Out:
# userId       347.011310
# movieId    12548.664363
# rating         3.543608
# dtype: float64

# %%
rating.std()
# Out:
# userId       195.163838
# movieId    26369.198969
# rating         1.058064
# dtype: float64

# %%
rating.any()
# Out:
# userId     True
# movieId    True
# rating     True
# dtype: bool

# %%
rating.count()
# Out:
# userId     100004
# movieId    100004
# rating     100004
# dtype: int64

# %%
a =rating.clip()
print(a)
print(rating.head())
# Out:
#         userId  movieId  rating
# 0          1.0     31.0     2.5
# 1          1.0   1029.0     3.0
# 2          1.0   1061.0     3.0
# 3          1.0   1129.0     2.0
# 4          1.0   1172.0     4.0
# 5          1.0   1263.0     2.0
# 6          1.0   1287.0     2.0
# 7          1.0   1293.0     2.0
# 8          1.0   1339.0     3.5
# 9          1.0   1343.0     2.0
# 10         1.0   1371.0     2.5
# 11         1.0   1405.0     1.0
# 12         1.0   1953.0     4.0
# 13         1.0   2105.0     4.0
# 14         1.0   2150.0     3.0
# 15         1.0   2193.0     2.0
# 16         1.0   2294.0     2.0
# 17         1.0   2455.0     2.5
# 18         1.0   2968.0     1.0
# 19         1.0   3671.0     3.0
# 20         2.0     10.0     4.0
# 21         2.0     17.0     5.0
# 22         2.0     39.0     5.0
# 23         2.0     47.0     4.0
# 24         2.0     50.0     4.0
# 25         2.0     52.0     3.0
# 26         2.0     62.0     3.0
# 27         2.0    110.0     4.0
# ...

# %%
type(rating["userId"][0])
# Out:
# numpy.int64

# %%
print(rating.rank())
print(rating)
# Out:
#          userId  movieId   rating
# 0          10.5   1632.5  15610.0
# 1          10.5  25026.5  27866.5
# 2          10.5  25725.0  27866.5
# 3          10.5  27354.5   9750.0
# 4          10.5  27771.5  62811.5
# 5          10.5  32439.5   9750.0
# 6          10.5  33614.5   9750.0
# 7          10.5  33942.5   9750.0
# 8          10.5  34621.5  43167.5
# 9          10.5  34696.0   9750.0
# 10         10.5  35264.0  15610.0
# 11         10.5  36319.5   2764.5
# 12         10.5  42675.5  62811.5
# 13         10.5  45756.0  62811.5
# 14         10.5  46656.5  27866.5
# 15         10.5  47123.5   9750.0
# 16         10.5  48059.0   9750.0
# 17         10.5  50618.0  15610.0
# 18         10.5  57564.0   2764.5
# 19         10.5  64614.5  27866.5
# 20         58.5    725.5  62811.5
# 21         58.5   1067.5  92457.0
# 22         58.5   2176.5  92457.0
# 23         58.5   2480.0  62811.5
# 24         58.5   2744.0  62811.5
# 25         58.5   2870.0  27866.5
# ...

# %%
rating.round()
# Out:
#         userId  movieId  rating
# 0            1       31     2.0
# 1            1     1029     3.0
# 2            1     1061     3.0
# 3            1     1129     2.0
# 4            1     1172     4.0
# 5            1     1263     2.0
# 6            1     1287     2.0
# 7            1     1293     2.0
# 8            1     1339     4.0
# 9            1     1343     2.0
# 10           1     1371     2.0
# 11           1     1405     1.0
# 12           1     1953     4.0
# 13           1     2105     4.0
# 14           1     2150     3.0
# 15           1     2193     2.0
# 16           1     2294     2.0
# 17           1     2455     2.0
# 18           1     2968     1.0
# 19           1     3671     3.0
# 20           2       10     4.0
# 21           2       17     5.0
# 22           2       39     5.0
# 23           2       47     4.0
# 24           2       50     4.0
# 25           2       52     3.0
# 26           2       62     3.0
# 27           2      110     4.0
# ...

# %%
rating['rating'].describe()
# Out:
# count    100004.000000
# mean          3.543608
# std           1.058064
# min           0.500000
# 25%           3.000000
# 50%           4.000000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
filter1 = (rating['rating']>4)*1

# %%
# filter1.any()

# %%
filter1.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: rating, dtype: int32

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# why we need to clean data?
#
# 1. missing value
# 2. invalid data (eg. negative values for age)
# 3. null values(NaN)
# 4. None values
# 5. outliers in data

# %% [markdown]
# # Data Quality Issues

# %% [markdown]
# 1. replace the value
# 2. fill gaps
# 3. drop fields
# 4. interpolation

# %%
rf = rating.replace(1.0,0.0)

# %%
rf.head()
# Out:
#    userId  movieId  rating
# 0     0.0     31.0     2.5
# 1     0.0   1029.0     3.0
# 2     0.0   1061.0     3.0
# 3     0.0   1129.0     2.0
# 4     0.0   1172.0     4.0

# %%
rf.fillna(method='ffill')
rf.fillna(method='bfill')
# Out:
#         userId  movieId  rating
# 0          0.0     31.0     2.5
# 1          0.0   1029.0     3.0
# 2          0.0   1061.0     3.0
# 3          0.0   1129.0     2.0
# 4          0.0   1172.0     4.0
# 5          0.0   1263.0     2.0
# 6          0.0   1287.0     2.0
# 7          0.0   1293.0     2.0
# 8          0.0   1339.0     3.5
# 9          0.0   1343.0     2.0
# 10         0.0   1371.0     2.5
# 11         0.0   1405.0     0.0
# 12         0.0   1953.0     4.0
# 13         0.0   2105.0     4.0
# 14         0.0   2150.0     3.0
# 15         0.0   2193.0     2.0
# 16         0.0   2294.0     2.0
# 17         0.0   2455.0     2.5
# 18         0.0   2968.0     0.0
# 19         0.0   3671.0     3.0
# 20         2.0     10.0     4.0
# 21         2.0     17.0     5.0
# 22         2.0     39.0     5.0
# 23         2.0     47.0     4.0
# 24         2.0     50.0     4.0
# 25         2.0     52.0     3.0
# 26         2.0     62.0     3.0
# 27         2.0    110.0     4.0
# ...

# %%
rf = rf.dropna(axis=0)

# %% [markdown]
# axis=0 means rows will be deleted with nan values

# %%
rf.shape
# Out:
# (100004, 3)

# %% [markdown]
# # Handling missing Data

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags.shape
# Out:
# (1296, 3)

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %% [markdown]
# # data ploting

# %%
# frame2.plot()

# %%
# rating.plot.bar()

# %%
# frame2.plot.hist()

# %%
# frame.boxplot()

# %% [markdown]
# # insert new column and row

# %%
rf['pk']= rf['rating']*2

# %%
rf.loc[0] = [1,2,3,4]

# %%
rf.head()
# Out:
#    userId  movieId  rating   pk
# 0     1.0      2.0     3.0  4.0
# 1     0.0   1029.0     3.0  6.0
# 2     0.0   1061.0     3.0  6.0
# 3     0.0   1129.0     2.0  4.0
# 4     0.0   1172.0     4.0  8.0

# %%
rf.drop(rf.index[0])
# Out:
#         userId  movieId  rating    pk
# 1          0.0   1029.0     3.0   6.0
# 2          0.0   1061.0     3.0   6.0
# 3          0.0   1129.0     2.0   4.0
# 4          0.0   1172.0     4.0   8.0
# 5          0.0   1263.0     2.0   4.0
# 6          0.0   1287.0     2.0   4.0
# 7          0.0   1293.0     2.0   4.0
# 8          0.0   1339.0     3.5   7.0
# 9          0.0   1343.0     2.0   4.0
# 10         0.0   1371.0     2.5   5.0
# 11         0.0   1405.0     0.0   0.0
# 12         0.0   1953.0     4.0   8.0
# 13         0.0   2105.0     4.0   8.0
# 14         0.0   2150.0     3.0   6.0
# 15         0.0   2193.0     2.0   4.0
# 16         0.0   2294.0     2.0   4.0
# 17         0.0   2455.0     2.5   5.0
# 18         0.0   2968.0     0.0   0.0
# 19         0.0   3671.0     3.0   6.0
# 20         2.0     10.0     4.0   8.0
# 21         2.0     17.0     5.0  10.0
# 22         2.0     39.0     5.0  10.0
# 23         2.0     47.0     4.0   8.0
# 24         2.0     50.0     4.0   8.0
# ...

# %%
del rf['pk']

# %%
rf
# Out:
#         userId  movieId  rating
# 0          1.0      2.0     3.0
# 1          0.0   1029.0     3.0
# 2          0.0   1061.0     3.0
# 3          0.0   1129.0     2.0
# 4          0.0   1172.0     4.0
# 5          0.0   1263.0     2.0
# 6          0.0   1287.0     2.0
# 7          0.0   1293.0     2.0
# 8          0.0   1339.0     3.5
# 9          0.0   1343.0     2.0
# 10         0.0   1371.0     2.5
# 11         0.0   1405.0     0.0
# 12         0.0   1953.0     4.0
# 13         0.0   2105.0     4.0
# 14         0.0   2150.0     3.0
# 15         0.0   2193.0     2.0
# 16         0.0   2294.0     2.0
# 17         0.0   2455.0     2.5
# 18         0.0   2968.0     0.0
# 19         0.0   3671.0     3.0
# 20         2.0     10.0     4.0
# 21         2.0     17.0     5.0
# 22         2.0     39.0     5.0
# 23         2.0     47.0     4.0
# 24         2.0     50.0     4.0
# 25         2.0     52.0     3.0
# 26         2.0     62.0     3.0
# 27         2.0    110.0     4.0
# ...

# %% [markdown]
# # Group By aggregate

# %%
rf.groupby('rating').count()
# Out:
#         userId  movieId
# rating
# 0.0       3326     3326
# 0.5       1101     1101
# 1.5       1687     1687
# 2.0       7271     7271
# 2.5       4448     4448
# 3.0      20065    20065
# 3.5      10538    10538
# 4.0      28750    28750
# 4.5       7723     7723
# 5.0      15095    15095

# %%
rf['rating'].head()
# Out:
# 0    3.0
# 1    3.0
# 2    3.0
# 3    2.0
# 4    4.0
# Name: rating, dtype: float64

# %%
rf[['userId','rating']].head()
# Out:
#    userId  rating
# 0     1.0     3.0
# 1     0.0     3.0
# 2     0.0     3.0
# 3     0.0     2.0
# 4     0.0     4.0

# %%
count =rf['rating'].value_counts()
count
# Out:
# 4.0    28750
# 3.0    20065
# 5.0    15095
# 3.5    10538
# 4.5     7723
# 2.0     7271
# 2.5     4448
# 0.0     3326
# 1.5     1687
# 0.5     1101
# Name: rating, dtype: int64

# %%
count.plot(kind = 'bar', figsize = (5,5))

# %% [markdown]
# # filter for selecting row

# %%
is_highly_rating = (rf['rating']>= 4.0)

# %%
is_highly_rating
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12         True
# 13         True
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25        False
# 26        False
# 27         True
# 28        False
# 29         True
#           ...
# 99974      True
# 99975      True
# 99976     False
# 99977      True
# 99978      True
# 99979      True
# 99980      True
# 99981      True
# 99982      True
# 99983      True
# 99984     False
# 99985     False
# 99986     False
# 99987      True
# 99988      True
# 99989      True
# 99990     False
# 99991      True
# 99992      True
# 99993     False
# 99994      True
# 99995      True
# 99996      True
# 99997      True
# ...

# %%
rf[is_highly_rating][:10]
# Out:
#     userId  movieId  rating
# 4      0.0   1172.0     4.0
# 12     0.0   1953.0     4.0
# 13     0.0   2105.0     4.0
# 20     2.0     10.0     4.0
# 21     2.0     17.0     5.0
# 22     2.0     39.0     5.0
# 23     2.0     47.0     4.0
# 24     2.0     50.0     4.0
# 27     2.0    110.0     4.0
# 29     2.0    150.0     5.0

# %%
is_animation = movies['genres'].str.contains('Animation')

# %%
movies[is_animation]
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 12         13                                       Balto (1995)
# 46         48                                  Pocahontas (1995)
# 211       239                              Goofy Movie, A (1995)
# 216       244                            Gumby: The Movie (1995)
# 279       313                          Swan Princess, The (1994)
# 328       364                              Lion King, The (1994)
# 354       392         Secret Adventures of Tom Thumb, The (1993)
# 494       551             Nightmare Before Christmas, The (1993)
# 500       558                             Pagemaster, The (1994)
# 521       588                                     Aladdin (1992)
# 526       594             Snow White and the Seven Dwarfs (1937)
# 527       595                        Beauty and the Beast (1991)
# ...

# %% [markdown]
# # Group by aggregate

# %%
rat_count = rf[['movieId','rating']].groupby('rating').count() #mean()

# %%
rat_count
# Out:
#         movieId
# rating
# 0.0        3326
# 0.5        1101
# 1.5        1687
# 2.0        7271
# 2.5        4448
# 3.0       20065
# 3.5       10538
# 4.0       28750
# 4.5        7723
# 5.0       15095

# %%
tags.head()
# Out:
#    userId  movieId                      tag
# 0      15      339  sandra 'boring' bullock
# 1      15     1955                  dentist
# 2      15     7478                 Cambodia
# 3      15    32892                  Russian
# 4      15    34162              forgettable

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags, on='movieId')
t.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        5  Father of the Bride Part II (1995)
# 2       47         Seven (a.k.a. Se7en) (1995)
# 3       47         Seven (a.k.a. Se7en) (1995)
# 4       47         Seven (a.k.a. Se7en) (1995)
#
#                                         genres  userId           tag
# 0  Adventure|Animation|Children|Comedy|Fantasy     501         Pixar
# 1                                       Comedy     431  steve martin
# 2                             Mystery|Thriller     364      biblical
# 3                             Mystery|Thriller     364         crime
# 4                             Mystery|Thriller     364          dark

# %%
p = t.merge(rating, on = ['movieId','userId'])

# %%
p.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        5  Father of the Bride Part II (1995)
# 2       47         Seven (a.k.a. Se7en) (1995)
# 3       47         Seven (a.k.a. Se7en) (1995)
# 4       47         Seven (a.k.a. Se7en) (1995)
#
#                                         genres  userId           tag  rating
# 0  Adventure|Animation|Children|Comedy|Fantasy     501         Pixar     5.0
# 1                                       Comedy     431  steve martin     4.5
# 2                             Mystery|Thriller     364      biblical     0.5
# 3                             Mystery|Thriller     364         crime     0.5
# 4                             Mystery|Thriller     364          dark     0.5

# %%
p.to_csv('output.csv')
